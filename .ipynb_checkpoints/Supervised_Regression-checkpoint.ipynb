# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("day.csv")

# %%
df
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
df.shape
# Out:
# (731, 16)

# %%
df.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
# 5        6  2011-01-06       1   0     1        0        4           1
# 6        7  2011-01-07       1   0     1        0        5           1
# 7        8  2011-01-08       1   0     1        0        6           0
# 8        9  2011-01-09       1   0     1        0        0           0
# 9       10  2011-01-10       1   0     1        0        1           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# ...

# %%
# Total count(sales) as a function of temp
# Independant variable = Temp
# Dependant variable = Count

# y = mx + c
# cnt = m(temp) + c

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()  # LinearRegression() object

# %%
#Fit and #Predict

# %% [markdown]
# # Simple Linear Regression

# %%
df["temp"].shape
# Out:
# (731,)

# %%
df["temp"].values
# Out:
# array([0.344167 , 0.363478 , 0.196364 , 0.2      , 0.226957 , 0.204348 ,
#        0.196522 , 0.165    , 0.138333 , 0.150833 , 0.169091 , 0.172727 ,
#        0.165    , 0.16087  , 0.233333 , 0.231667 , 0.175833 , 0.216667 ,
#        0.292174 , 0.261667 , 0.1775   , 0.0591304, 0.0965217, 0.0973913,
#        0.223478 , 0.2175   , 0.195    , 0.203478 , 0.196522 , 0.216522 ,
#        0.180833 , 0.192174 , 0.26     , 0.186957 , 0.211304 , 0.233333 ,
#        0.285833 , 0.271667 , 0.220833 , 0.134783 , 0.144348 , 0.189091 ,
#        0.2225   , 0.316522 , 0.415    , 0.266087 , 0.318261 , 0.435833 ,
#        0.521667 , 0.399167 , 0.285217 , 0.303333 , 0.182222 , 0.221739 ,
#        0.295652 , 0.364348 , 0.2825   , 0.343478 , 0.407273 , 0.266667 ,
#        0.335    , 0.198333 , 0.261667 , 0.384167 , 0.376522 , 0.261739 ,
#        0.2925   , 0.295833 , 0.389091 , 0.316522 , 0.329167 , 0.384348 ,
#        0.325217 , 0.317391 , 0.365217 , 0.415    , 0.54     , 0.4725   ,
# ...

# %%
df["temp"].values.reshape(-1,1)
# Out:
# array([[0.344167 ],
#        [0.363478 ],
#        [0.196364 ],
#        [0.2      ],
#        [0.226957 ],
#        [0.204348 ],
#        [0.196522 ],
#        [0.165    ],
#        [0.138333 ],
#        [0.150833 ],
#        [0.169091 ],
#        [0.172727 ],
#        [0.165    ],
#        [0.16087  ],
#        [0.233333 ],
#        [0.231667 ],
#        [0.175833 ],
#        [0.216667 ],
#        [0.292174 ],
#        [0.261667 ],
#        [0.1775   ],
#        [0.0591304],
#        [0.0965217],
#        [0.0973913],
#        [0.223478 ],
#        [0.2175   ],
#        [0.195    ],
#        [0.203478 ],
#        [0.196522 ],
#        [0.216522 ],
#        [0.180833 ],
#        [0.192174 ],
#        [0.26     ],
#        [0.186957 ],
#        [0.211304 ],
#        [0.233333 ],
#        [0.285833 ],
#        [0.271667 ],
#        [0.220833 ],
#        [0.134783 ],
#        [0.144348 ],
#        [0.189091 ],
#        [0.2225   ],
#        [0.316522 ],
#        [0.415    ],
# ...

# %%
df["temp"].values.reshape(-1,1).shape
# Out:
# (731, 1)

# %%
lr.fit(df["temp"].values.reshape(-1,1),df["cnt"].values.reshape(-1,1))
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr.intercept_
# Out:
# array([1214.64211903])

# %%
lr.coef_
# Out:
# array([[6640.70999855]])

# %%
lr.predict([[0.45]])
# Out:
# array([[4202.96161838]])

# %%
lr.predict([[0.15]])
# Out:
# array([[2210.74861881]])

# %%
lr.predict([[0.344167]])
# Out:
# array([[3500.1553571]])

# %%
plt.scatter(df["temp"],df["cnt"])

# %%
m = lr.coef_
c = lr.intercept_

# %%
plt.scatter(df["temp"],df["cnt"])
x = df["temp"]

# %%
x
# Out:
# 0      0.344167
# 1      0.363478
# 2      0.196364
# 3      0.200000
# 4      0.226957
#          ...
# 726    0.254167
# 727    0.253333
# 728    0.253333
# 729    0.255833
# 730    0.215833
# Name: temp, Length: 731, dtype: float64

# %%
import numpy as np

# %%
X = np.array(x)

# %%
X = X.reshape(-1,1)
X
# Out:
# array([[0.344167 ],
#        [0.363478 ],
#        [0.196364 ],
#        [0.2      ],
#        [0.226957 ],
#        [0.204348 ],
#        [0.196522 ],
#        [0.165    ],
#        [0.138333 ],
#        [0.150833 ],
#        [0.169091 ],
#        [0.172727 ],
#        [0.165    ],
#        [0.16087  ],
#        [0.233333 ],
#        [0.231667 ],
#        [0.175833 ],
#        [0.216667 ],
#        [0.292174 ],
#        [0.261667 ],
#        [0.1775   ],
#        [0.0591304],
#        [0.0965217],
#        [0.0973913],
#        [0.223478 ],
#        [0.2175   ],
#        [0.195    ],
#        [0.203478 ],
#        [0.196522 ],
#        [0.216522 ],
#        [0.180833 ],
#        [0.192174 ],
#        [0.26     ],
#        [0.186957 ],
#        [0.211304 ],
#        [0.233333 ],
#        [0.285833 ],
#        [0.271667 ],
#        [0.220833 ],
#        [0.134783 ],
#        [0.144348 ],
#        [0.189091 ],
#        [0.2225   ],
#        [0.316522 ],
#        [0.415    ],
# ...

# %%
Y = ((m*X) + c).reshape(-1,1)
Y
# Out:
# array([[3500.1553571 ],
#        [3628.39410788],
#        [2518.63849718],
#        [2542.78411874],
#        [2721.79773817],
#        [2571.65792581],
#        [2519.68772936],
#        [2310.35926879],
#        [2133.27145526],
#        [2216.28033024],
#        [2337.52641339],
#        [2361.67203495],
#        [2310.35926879],
#        [2282.9331365 ],
#        [2764.13890512],
#        [2753.07548226],
#        [2382.2980802 ],
#        [2653.46483228],
#        [3154.88492215],
#        [2952.29678222],
#        [2393.36814377],
#        [1607.30995753],
#        [1855.6147373 ],
#        [1861.38949871],
#        [2698.69470809],
#        [2658.99654371],
#        [2509.58056875],
#        [2565.88050811],
#        [2519.68772936],
#        [2652.50192934],
#        [2415.5016302 ],
#        [2490.81392229],
#        [2941.22671865],
#        [2456.16933823],
#        [2617.85070456],
#        [2764.13890512],
#        [3112.77618004],
#        [3018.70388221],
# ...

# %%
plt.plot(X, Y)

# %%
plt.scatter(df["temp"], df["cnt"])
plt.plot(X, Y, color="red")

# %% [markdown]
# # Multipal Linear Regression

# %%
df.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
df[["temp","hum","casual"]]
# Out:
#          temp       hum  casual
# 0    0.344167  0.805833     331
# 1    0.363478  0.696087     131
# 2    0.196364  0.437273     120
# 3    0.200000  0.590435     108
# 4    0.226957  0.436957      82
# ..        ...       ...     ...
# 726  0.254167  0.652917     247
# 727  0.253333  0.590000     644
# 728  0.253333  0.752917     159
# 729  0.255833  0.483333     364
# 730  0.215833  0.577500     439
#
# [731 rows x 3 columns]

# %%
lr.fit(df[["temp","hum","casual"]], df["cnt"].values.reshape(-1,1))
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr.coef_
# Out:
# array([[ 4.22992224e+03, -1.59147475e+03,  1.26015129e+00]])

# %%
lr.intercept_
# Out:
# array([2339.35657509])

# %%
lr.coef_[0,0]
# Out:
# 4229.922238961116

# %%
c = lr.intercept_
m1 = lr.coef_[0,0]
m2 = lr.coef_[0,1]
m3 = lr.coef_[0,2]
X1 = np.array(df["temp"]).reshape(-1,1)
X2 = np.array(df["hum"]).reshape(-1,1)
X3 = np.array(df["casual"]).reshape(-1,1)
Y = (m1*X1) + (m2*X2) + (m3*X3)

# %%
plt.scatter(df["temp"], df["cnt"])

# %%
plt.scatter(df["hum"], df["cnt"])

# %%
plt.scatter(df["casual"], df["cnt"])

# %%
lr.predict([])

# %%
df[["temp","hum","casual","cnt"]].head(10)
# Out:
#        temp       hum  casual   cnt
# 0  0.344167  0.805833     331   985
# 1  0.363478  0.696087     131   801
# 2  0.196364  0.437273     120  1349
# 3  0.200000  0.590435     108  1562
# 4  0.226957  0.436957      82  1600
# 5  0.204348  0.518261      88  1606
# 6  0.196522  0.498696     148  1510
# 7  0.165000  0.535833      68   959
# 8  0.138333  0.434167      54   822
# 9  0.150833  0.482917      41  1321

# %%
lr.predict([[0.344167,0.805833,331]])
# Out:
# array([[2929.8034295]])

# %%
X = np.array([X1,X2,X3]).reshape(731,3)

# %%
X
# Out:
# array([[[3.44167e-01],
#         [3.63478e-01],
#         [1.96364e-01],
#         ...,
#         [2.53333e-01],
#         [2.55833e-01],
#         [2.15833e-01]],
#
#        [[8.05833e-01],
#         [6.96087e-01],
#         [4.37273e-01],
#         ...,
#         [7.52917e-01],
#         [4.83333e-01],
#         [5.77500e-01]],
#
#        [[3.31000e+02],
#         [1.31000e+02],
#         [1.20000e+02],
#         ...,
#         [1.59000e+02],
#         [3.64000e+02],
#         [4.39000e+02]]])

# %%
X
# Out:
# array([[3.44167e-01, 3.63478e-01, 1.96364e-01],
#        [2.00000e-01, 2.26957e-01, 2.04348e-01],
#        [1.96522e-01, 1.65000e-01, 1.38333e-01],
#        ...,
#        [4.08000e+02, 1.74000e+02, 4.40000e+02],
#        [9.00000e+00, 2.47000e+02, 6.44000e+02],
#        [1.59000e+02, 3.64000e+02, 4.39000e+02]])

# %%
X.shape
# Out:
# (731, 3)

# %%
Y
# Out:
# array([[ 5.90446854e+02],
#        [ 5.94758612e+02],
#        [ 2.85913668e+02],
#        [ 4.24183949e+01],
#        [ 3.67936836e+02],
#        [ 1.50470169e+02],
#        [ 2.24113079e+02],
#        [-6.91372309e+01],
#        [-3.77798137e+01],
#        [-7.88721464e+01],
#        [-3.22902686e+02],
#        [-1.92035166e+02],
#        [-2.83385754e+00],
#        [-1.07420737e+02],
#        [ 4.72986002e+02],
#        [ 5.26355460e+02],
#        [ 3.57799415e+01],
#        [-4.43495347e+02],
#        [ 1.53706214e+02],
#        [ 3.54680245e+02],
#        [ 1.17886492e+02],
#        [-2.69278835e+02],
#        [-9.74117606e+01],
#        [-2.62259564e+02],
#        [ 1.97811217e+02],
#        [-4.09793738e+02],
#        [-2.50401782e+02],
#        [-3.53526041e+02],
#        [-5.09547732e+01],
#        [-5.70292802e+01],
#        [-1.43016996e+02],
#        [-4.48123561e+02],
#        [-4.35458988e+01],
#        [ 1.70893778e+02],
#        [ 7.33347254e+01],
# ...

# %%
Y.shape
# Out:
# (731, 1)

# %%
plt.plot(X,Y)
